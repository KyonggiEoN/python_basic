# %% [markdown]
# # **코랩을 시작합니다**
# **구글 코랩(Google Colab)**은 Google이 제공하는 무료 클라우드 기반 Jupyter 노트북 환경입니다. 코랩은 파이썬 코드를 쉽게 작성하고 실행할 수 있는 환경을 제공하며, 특히 머신러닝과 딥러닝 관련 실습에 많이 사용됩니다.

# %% [markdown]
# ## **코랩 환경**

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ## **셀의 종류**

# %% [markdown]
# **텍스트 셀** 마크다운 문법을 사용하여 텍스트 사용가능
#
# **코드 셀** Python 코드 작성 및 실행 가능

# %% [markdown]
# ## **셀의 조작**

# %% [markdown]
# ### **1 이동**

# %% [markdown]
# 위로 이동 Ctrl + M K
#
# 아래로 이동 Ctrl + M J

# %% [markdown]
# ### **2 삽입**

# %% [markdown]
# 상단 툴바 + 버튼
#
# 위에 코드 삽입 Ctrl + M A
#
# 아래에 코드 삽입 Ctrl + M B

# %% [markdown]
# ### **3 변경**

# %% [markdown]
# 코드 셀로 변경 Ctrl + M Y
#
# 텍스트 셀로 변경 Ctrl + M M

# %% [markdown]
# ### **4 삭제**

# %% [markdown]
# 툴바 위, 수정 메뉴 선택 후 셀 삭제 클릭
#
# 셀 상하단의 휴지통 아이콘 클릭
#
#   - Ctrl + M D
#
#   - **되돌리기** Ctrl+ M Z
#
#   - **취소한 내용 재실행** Ctrl+ Shift+ Y

# %% [markdown]
# ### **5 실행**

# %% [markdown]
# 실행 버튼 (▶️) 클릭하기
#
# **현재 셀 실행**
#
#   - 커서 그대로 유지 Ctrl+ Enter
#
#   - 커서 다음 셀로 이동 Shift+ Enter
#
#   - 바로 아래 새 셀 삽입 Alt+ Enter

# %%
print(100)

# %% [markdown]
# ### 6 주석 처리

# %% [markdown]
# 문자열의 아무 곳에나 커서를 두고
#
# Ctrl + /
