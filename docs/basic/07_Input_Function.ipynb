# %% [markdown]
# # **Input**

# %% [markdown]
# Input() 함수는 사용자로부터 키보드 입력을 받는데 사용되는 내장 함수.
#
# 프로그램 실행 중 사용자가 값을 입력하면, 입력한 값이 문자열로 반환되어 변수에 저장하거나 처리할 수 있음.

# %%
x = input('값을 입력하세요! ')
print('입력하신 값은 ', x, ' 입니다!')
# Out:
# 값을 입력하세요!컄
# 입력하신 값은  컄  입니다!

# %%
x = input('값을 입력하세요! ')
print(f'입력하신 값은 {x} 입니다!')
del x
# Out:
# 값을 입력하세요! asd
# 입력하신 값은 asd 입니다!

# %%
name, age, weight = '김사과', 20, 50.5
print(name)
print(age)
print(weight)

del name, age, weight

#input은 문자열로 값을 받아오므로 string의 함수와 메서드를 사용할 수 있다.
name, age, weight = input('이름, 나이, 몸무게를 차례로 입력하세요.').strip().split(' ')
print(name)
print(age)
print(weight)

del name, age, weight
# Out:
# 김사과
# 20
# 50.5
# 이름, 나이, 몸무게를 차례로 입력하세요.     3 2   1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-a3243b4ec025> in <cell line: 9>()
#       7
#       8 #input은 문자열로 값을 받아오므로 string의 함수와 메서드를 사용할 수 있다.
# ----> 9 name, age, weight = input('이름, 나이, 몸무게를 차례로 입력하세요.').strip().split(' ')
#      10 print(name)
#      11 print(age)
#
# ValueError: too many values to unpack (expected 3)

# %%
num1 = input('첫번째 숫자를 입력하세요')
num2 = input('두번째 숫자를 입력하세요')
print('결과: ', num1 + num2) #문자열은 합친다...
# Out:
# 첫번째 숫자를 입력하세요1233
# 두번째 숫자를 입력하세요321
# 결과:  1233321

# %%
num1 = input('첫번째 숫자를 입력하세요')
num2 = input('두번째 숫자를 입력하세요')
print('결과: ', int(num1 + num2))
# 문자열을 먼저 계산하고 int를 입력하므로 이상해진다!
# Out:
# 첫번째 숫자를 입력하세요213
# 두번째 숫자를 입력하세요123
# 결과:  213123

# %%
num1 = int(input('Input num1 : '))
num2 = int(input('Input num2 : '))
print(num1 + num2)
# Out:
# Input num1 : 1
# Input num2 : 3
# 4
