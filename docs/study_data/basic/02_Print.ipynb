# %% [markdown]
# # **Print 함수**
# print() 는 사용자에게 출력값을 보여주는 가장 기초적인 함수로, 디버깅 할 때 유용합니다.
#
# ```
# print(값1, 값2, ..., sep='구분자', end='끝 문자')
# ```

# %%
print(10, 20, 30, 40, sep='😎')
print('Hello ', end='')
print('Python')
# Out:
# 10😎20😎30😎40
# Hello Python

# %% [markdown]
# ## **escape 문자**
# 1. \n: 줄바꿈
# 2. \t: 탭
# 3. \\\\: 백슬래시
# 4. \\" 또는 \\': 큰따옴표나 작은따옴표. 문자열을 감싸는 따옴표와 구분하기 위해 사용
# 5. \r: 캐리지 리턴. 문자열을 출력한 후 커서를 줄의 처음으로 이동
# 6. \b: 백스페이스. 문자열 내에서 한 글자를 삭제

# %%
print("Hello\nPython!")
print("Name:\tqpple")
print("Backslash: \\")
print("C:\\Users\\Administrator\\Documents")
# Out:
# Hello
# Python!
# Name:	qpple
# Backslash: \
# C:\Users\Administrator\Documents

# %% [markdown]
# ## **print 함수 내 연산**

# %%
print(10)
print(10 + 5)
print('덧셈: ', 10 + 5)
print('뺄셈: ', 10 - 5)
print('곱셈: ', 10 * 5)
print('나눗셈: ', 10 / 3)
print('정수 나눗셈: ', 10 // 3)
print('나머지: ', 11 % 5)
print('거듭제곱: ', 10 ** 5)
# Out:
# 10
# 15
# 덧셈:  15
# 뺄셈:  5
# 곱셈:  50
# 나눗셈:  3.3333333333333335
# 정수 나눗셈:  3
# 나머지:  1
# 거듭제곱:  100000

# %% [markdown]
# ## **출력서식 지정**

# %% [markdown]
# ### 1. % 서식지정자
#
#   - %s : 문자열 출력
#
#   - %d : 정수 출력
#
#   - %nf: 소수점 이하 n자리까지 출력

# %%
print('정수: ', 100)
print('정수: %d' % 100)
print('정수: %d' % 100.5)
print('실수: %f' % 100.5)
print('실수: %f' % 100)
print('문자열: %s' % '파이썬')
print('문자열: %s' % 100)
print('5 + 3 = 8')
print('%d + %d = %d' % (5, 3, 5+3))
print("이름: %s, 나이: %d" % ('김사과', 20))
print("몸무게: %.2f" % 50.12345)
# Out:
# 정수:  100
# 정수: 100
# 정수: 100
# 실수: 100.500000
# 실수: 100.000000
# 문자열: 파이썬
# 문자열: 100
# 5 + 3 = 8
# 5 + 3 = 8
# 이름: 김사과, 나이: 20
# 몸무게: 50.12

# %% [markdown]
# ### 2. str.format() 메서드
#
#   - {}: 중괄호 안에 변수나 표현식을 넣어 값을 출력
#   - {:d}: 정수를 출력
#   - {:f}: 부동 소수점 숫자를 출력
#   - {:s}: 문자열을 출력
#   - {:x}: 정수를 16진수로 출력
#   - {:0n}: n 자리의 정수를 0으로 채워서 출력
#   - {:n.mf}: 전체 길이 n과 소수점 이하 자리수 m을 지정하여 부동 소수점 숫자를 출력

# %%
print('I like {} {}'.format("Coffee", "Bread"))
print("이름: {}, 나이: {}, 점수: {:.2f}".format('김사과', 20, 95.678))
print("첫 번째: {0}, 두 번째: {1}, 다시 첫 번째: {0}".format("사과", "오렌지"))
print("이름: {name}, 나이: {age}".format(name= "김사과", age= 20))
print("숫자: {:,}".format(1234567890)) #큰 숫자를 1000단위로 끊음
print("16진수: {:x}, 8진수: {:o}, 2진수: {:b}".format(255, 255, 255))
print("{:05d}".format(123)) #공간을 확보하고 앞을 0으로 채움
print("{:5d}".format(123)) #공간 확보
# Out:
# I like Coffee Bread
# 이름: 김사과, 나이: 20, 점수: 95.68
# 첫 번째: 사과, 두 번째: 오렌지, 다시 첫 번째: 사과
# 이름: 김사과, 나이: 20
# 숫자: 1,234,567,890
# 16진수: ff, 8진수: 377, 2진수: 11111111
# 00123
#   123
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-1fd6a86ae526> in <cell line: 9>()
#       7 print("{:05d}".format(123)) #공간을 확보하고 앞을 0으로 채움
#       8 print("{:5d}".format(123)) #공간 확보
# ----> 9 print("{:r5d}".format(123))
#
# ValueError: Invalid format specifier

# %% [markdown]
# ### 3. f-string
#   문자열 앞에 f를 붙이고 중괄호 {} 안에 변수를 넣어 사용

# %%
a, b = 10, 12
print(f'a + b = {a + b}')
print(f'10+ 20 = {10 + 20}')
print(f"3.14159를 소수 둘째자리까지 표현 {3.14159:.2f}")
# Out:
# a + b = 22
# 10+ 20 = 30
# 3.14159를 소수 둘째자리까지 표현 3.14

# %% [markdown]
# ## **주석문**

# %%
#한 줄 주석입니다.
"""여러줄을 주석처리합니다.
줄바꿈을 하더라도 주석이 됩니다.
와우!"""
print("주석은 출력되지 않습니다")
# Out:
# 주석은 출력되지 않습니다
